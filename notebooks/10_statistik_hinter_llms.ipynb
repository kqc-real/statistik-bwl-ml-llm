# %% [markdown]
# <a href="https://colab.research.google.com/github/kqc-real/statistik-bwl-ml-llm/blob/main/notebooks/10_statistik_hinter_llms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# **Studentische Übung · Browser-Version**
#
# 1. Oben auf **„Open in Colab“** klicken.
# 2. In Colab: **Datei → Kopie in Drive speichern**.
# 3. Zellen von oben nach unten ausführen.
#
# > KI- und Coding-Agenten sind erlaubt. Entscheidend ist, dass ihr jede Kennzahl, Grafik und Modellentscheidung fachlich erklären könnt.

# %% [markdown]
# # Übung 10: Statistik hinter LLMs
#
# **Von Logits zu Tokens**
#
# **Datensatz:** kleiner didaktischer Token-Datensatz
# **Dauer:** ca. 90 Minuten
# **Arbeitsform:** Zweiergruppen; KI-Agenten und Coding-Assistenten sind ausdrücklich erlaubt.
#
# > **Kursregel:** Der Agent darf rechnen und Code erzeugen. Ihr müsst jedoch jede Kennzahl, Grafik und Modellentscheidung fachlich erklären können.
#
# Am Ende des Notebooks gibt es einen **Management-Checkpoint**. Dort zählt nicht der Code, sondern eine kurze, belastbare Entscheidungsvorlage.

# %% [markdown]
# ## Lernziele
#
# Nach dieser Übung könnt ihr:
#
# - Logits mit Softmax in Wahrscheinlichkeiten umwandeln
# - den Einfluss der Temperatur auf eine Verteilung erklären
# - Entropie als Unsicherheitsmaß interpretieren
# - Sampling, Argmax, Top-k und Top-p unterscheiden

# %% [markdown]
# ## Setup

# %%
#@title Setup ausführen
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 50)
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")
RNG = np.random.default_rng(42)

print("Setup abgeschlossen.")

# %% [markdown]
# ## 1. Geschäftssituation
#
# Ein Sprachmodell soll den Satzanfang „Der Umsatz ist im letzten Quartal …“ fortsetzen. Wir untersuchen nicht das gesamte neuronale Netz, sondern nur die statistische Entscheidung am Ausgang.

# %% [markdown]
# ## 2. Token und Logits

# %%
tokens = pd.DataFrame({
    "Token": ["gestiegen", "gefallen", "stabil", "stark", "überraschend", "gesunken"],
    "Logit": [3.8, 2.9, 1.7, 1.1, 0.7, 2.2],
})
tokens

# %% [markdown]
# ## 3. Softmax: von Scores zu Wahrscheinlichkeiten

# %%
# TODO 1: Implementiert softmax(logits).
# Tipp: Für numerische Stabilität zuerst max(logits) abziehen.

def softmax(logits):
    ...

tokens["Wahrscheinlichkeit"] = ...
tokens

# %% [markdown]
# ## 4. Wahrscheinlichkeiten prüfen

# %%
# TODO 2:
# a) Prüft, ob die Wahrscheinlichkeiten zu 1 summieren.
# b) Ermittelt das wahrscheinlichste Token.

# %% [markdown]
# ## 5. Temperatur

# %%
# TODO 3: Implementiert probabilities_with_temperature(logits, T).
# Vergleicht T = 0.2, 1.0 und 1.5 in einer Tabelle.

# %%
# TODO 4: Zeichnet für T=0.2 und T=1.5 jeweils ein eigenes Balkendiagramm.

# %% [markdown]
# ## 6. Entropie: Unsicherheit der Verteilung

# %%
# TODO 5: Implementiert Entropie H(p) = -sum(p * log(p)).
# Berechnet die Entropie für T=0.2, 1.0, 1.5.

# %% [markdown]
# ## 7. Sampling statt immer Argmax

# %%
# TODO 6: Sampelt 10.000 Tokens bei T=1.0.
# Vergleicht die empirischen Häufigkeiten mit den Softmax-Wahrscheinlichkeiten.

# %% [markdown]
# > **Agentenauftrag**
# > Kopiert bei Bedarf diesen Auftrag in euren Coding-Agenten:
# >
# > *„Erkläre den Unterschied zwischen Logit, Softmax-Wahrscheinlichkeit, Temperatur und Sampling so, dass ein BWL-Student die statistische Kette nachvollziehen kann. Verwende ein einziges Beispiel mit sechs möglichen nächsten Tokens.“*
# >
# > Prüft den Vorschlag des Agenten. Übernehmt keine Auswertung, die ihr nicht fachlich begründen könnt.

# %% [markdown]
# ## 8. Top-k und Top-p
#
# Erklärt konzeptionell:
#
# - Was passiert bei Top-k = 3?
# - Warum ist Top-p dynamischer als Top-k?
# - Warum verändert die Auswahlregel die erzeugten Texte, obwohl das zugrunde liegende Modell unverändert bleibt?

# %%
# TODO 7 (Challenge): Implementiert Top-k=3.
# Setzt alle anderen Wahrscheinlichkeiten auf 0 und normalisiert neu.

# %% [markdown]
# ## Management-Checkpoint
#
# Ein Kollege sagt: „Temperatur 0,2 macht das Modell intelligenter.“ Korrigiert die Aussage in höchstens 70 Wörtern und beschreibt präzise, was sich statistisch verändert.
