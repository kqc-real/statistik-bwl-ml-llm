# %% [markdown]
# <a href="https://colab.research.google.com/github/kqc-real/statistik-bwl-ml-llm/blob/main/notebooks/06_korrelation_kausalitaet_leakage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# **Studentische Übung · Browser-Version**
#
# 1. Oben auf **„Open in Colab“** klicken.
# 2. In Colab: **Datei → Kopie in Drive speichern**.
# 3. Zellen von oben nach unten ausführen.
#
# > KI- und Coding-Agenten sind erlaubt. Entscheidend ist, dass ihr jede Kennzahl, Grafik und Modellentscheidung fachlich erklären könnt.

# %% [markdown]
# # Übung 6: Korrelation, Kausalität und Leakage
#
# **Das fast perfekte Modell, das nicht eingesetzt werden darf**
#
# **Datensatz:** UCI Bike Sharing Dataset
# **Dauer:** ca. 90 Minuten
# **Arbeitsform:** Zweiergruppen; KI-Agenten und Coding-Assistenten sind ausdrücklich erlaubt.
#
# > **Kursregel:** Der Agent darf rechnen und Code erzeugen. Ihr müsst jedoch jede Kennzahl, Grafik und Modellentscheidung fachlich erklären können.
#
# Am Ende des Notebooks gibt es einen **Management-Checkpoint**. Dort zählt nicht der Code, sondern eine kurze, belastbare Entscheidungsvorlage.

# %% [markdown]
# ## Lernziele
#
# Nach dieser Übung könnt ihr:
#
# - Korrelationen berechnen und visualisieren
# - Korrelation von Kausalität unterscheiden
# - Data Leakage am Prognosezeitpunkt erkennen
# - statistische Güte kritisch statt mechanisch bewerten

# %% [markdown]
# ## Setup

# %%
#@title Setup und Kursdaten laden
import importlib.util
import sys
import urllib.request
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 50)
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")
RNG = np.random.default_rng(42)

MODULE_URL = "https://raw.githubusercontent.com/kqc-real/statistik-bwl-ml-llm/main/course_data.py"
module_path = Path("course_data.py")
if not module_path.exists():
    urllib.request.urlretrieve(MODULE_URL, module_path)

spec = importlib.util.spec_from_file_location("course_data", module_path)
course_data = importlib.util.module_from_spec(spec)
sys.modules["course_data"] = course_data
spec.loader.exec_module(course_data)

df = course_data.bike_sharing()
print("Datensatz: bike_sharing")
print("Form:", df.shape)
df.head()

# %% [markdown]
# ## 1. Geschäftssituation
#
# Ein Bike-Sharing-Anbieter möchte Nachfrage erklären und prognostizieren. Ein Analyst präsentiert ein fast perfektes Modell. Ist das ein Erfolg oder ein Warnsignal?

# %% [markdown]
# ## 2. Korrelationen untersuchen

# %%
# TODO 1: Berechnet Pearson-Korrelationen von
# temp, atemp, hum, windspeed, casual, registered mit cnt.

features = ["temp", "atemp", "hum", "windspeed", "casual", "registered", "cnt"]
corr = ...
corr["cnt"].sort_values(ascending=False)

# %% [markdown]
# ## 3. Visualisieren, nicht nur korrelieren

# %%
# TODO 2: Scatterplot temp gegen cnt.

# %% [markdown]
# ## 4. Die Leakage-Falle
#
# Im Datensatz gilt: `cnt = casual + registered`. Prüft diese Beziehung.

# %%
# TODO 3: Prüft, für wie viele Zeilen die Gleichung exakt gilt.

share_exact = ...
share_exact

# %% [markdown]
# > **Agentenauftrag**
# > Kopiert bei Bedarf diesen Auftrag in euren Coding-Agenten:
# >
# > *„Ich will cnt vorhersagen. Die Variablen casual und registered ergeben zusammen exakt cnt. Erkläre, warum ihre Verwendung als Features Data Leakage wäre, obwohl sie eine perfekte Prognose liefern. Formuliere die Antwort aus Sicht eines Prognosezeitpunkts.“*
# >
# > Prüft den Vorschlag des Agenten. Übernehmt keine Auswertung, die ihr nicht fachlich begründen könnt.

# %% [markdown]
# ## 5. Korrelation ist nicht Kausalität
#
# Diskutiert die Aussage: „Höhere Temperaturen verursachen mehr Bike-Sharing-Nachfrage.“ Nennt mindestens zwei alternative Erklärungen oder Confounder.

# %%
# TODO 4: Vergleicht mittlere Nachfrage nach season und workingday.
# Die Variablencodierungen dürfen als Kategorien behandelt werden.

# %% [markdown]
# ## 6. Zeitliche Struktur
#
# Sortiert nach Datum bzw. instant und zeichnet cnt über die Zeit.

# %%
# TODO 5: Zeitreihe zeichnen.

# %% [markdown]
# ## Management-Checkpoint
#
# Schreibt einen kurzen Audit-Vermerk: Warum kann ein Modell mit nahezu perfekter Güte dennoch unbrauchbar sein? Nennt den konkreten Leakage-Mechanismus und eine Regel für zukünftige Projekte.
