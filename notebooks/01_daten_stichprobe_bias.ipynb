# %% [markdown]
# <a href="https://colab.research.google.com/github/kqc-real/statistik-bwl-ml-llm/blob/main/notebooks/01_daten_stichprobe_bias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# **Studentische Übung · Browser-Version**
#
# 1. Oben auf **„Open in Colab“** klicken.
# 2. In Colab: **Datei → Kopie in Drive speichern**.
# 3. Zellen von oben nach unten ausführen.
#
# > KI- und Coding-Agenten sind erlaubt. Entscheidend ist, dass ihr jede Kennzahl, Grafik und Modellentscheidung fachlich erklären könnt.

# %% [markdown]
# # Übung 1: Daten, Stichprobe und Bias
#
# **Vom Rohdatensatz zur belastbaren Analysepopulation**
#
# **Datensatz:** UCI Online Retail
# **Dauer:** ca. 90 Minuten
# **Arbeitsform:** Zweiergruppen; KI-Agenten und Coding-Assistenten sind ausdrücklich erlaubt.
#
# > **Kursregel:** Der Agent darf rechnen und Code erzeugen. Ihr müsst jedoch jede Kennzahl, Grafik und Modellentscheidung fachlich erklären können.
#
# Am Ende des Notebooks gibt es einen **Management-Checkpoint**. Dort zählt nicht der Code, sondern eine kurze, belastbare Entscheidungsvorlage.

# %% [markdown]
# ## Lernziele
#
# Nach dieser Übung könnt ihr:
#
# - die Beobachtungseinheit eines betrieblichen Datensatzes bestimmen
# - Datenqualitätsprobleme systematisch identifizieren
# - eine Analysepopulation transparent definieren
# - Stichprobenfehler und mögliche Verzerrungen argumentativ beurteilen

# %% [markdown]
# ## Setup

# %%
#@title Setup und Kursdaten laden
import importlib.util
import sys
import urllib.request
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 50)
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")
RNG = np.random.default_rng(42)

MODULE_URL = "https://raw.githubusercontent.com/kqc-real/statistik-bwl-ml-llm/main/course_data.py"
module_path = Path("course_data.py")
if not module_path.exists():
    urllib.request.urlretrieve(MODULE_URL, module_path)

spec = importlib.util.spec_from_file_location("course_data", module_path)
course_data = importlib.util.module_from_spec(spec)
sys.modules["course_data"] = course_data
spec.loader.exec_module(course_data)

df = course_data.online_retail()
print("Datensatz: online_retail")
print("Form:", df.shape)
df.head()

# %% [markdown]
# ## 1. Geschäftssituation
#
# Ein Onlinehändler möchte seinen Umsatz besser verstehen. Bevor Kennzahlen berechnet werden, soll geprüft werden, ob die Rohdaten überhaupt sinnvoll interpretierbar sind.

# %% [markdown]
# ## Daten laden
#
# Die didaktisch vorbereiteten Kursdaten werden automatisch aus dem Kursrepository geladen. Es ist kein Download und kein Dateiupload nötig.

# %% [markdown]
# ## 3. Was ist hier überhaupt eine Beobachtung?
#
# Beantwortet zuerst ohne Code:
#
# 1. Ist eine Zeile ein Kunde, eine Bestellung oder eine Bestellposition?
# 2. Welche Variable identifiziert eine Rechnung?
# 3. Welche Variable identifiziert einen Kunden?
# 4. Welche Schlussfolgerungen wären problematisch, wenn man Zeilen fälschlich als Kunden interpretiert?

# %% [markdown]
# > **Agentenauftrag**
# > Kopiert bei Bedarf diesen Auftrag in euren Coding-Agenten:
# >
# > *„Untersuche die Struktur dieses pandas-DataFrames. Gib mir keinen fertigen Bericht, sondern schlage genau fünf Prüfungen vor, mit denen ich Beobachtungseinheit, Datentypen, fehlende Werte und unplausible Werte untersuchen kann.“*
# >
# > Prüft den Vorschlag des Agenten. Übernehmt keine Auswertung, die ihr nicht fachlich begründen könnt.

# %% [markdown]
# ## 4. Daten-Audit
#
# Ermittelt Datentypen, fehlende Werte und auffällige Werte. Notiert zu jedem Fund: **Problem – mögliche Ursache – statistische Folge**.

# %%
# TODO 1: Datentypen und fehlende Werte untersuchen
# Tipp: df.info(), df.isna().sum(), df.describe(include="all")

# %%
# TODO 2: Prüft mindestens diese drei Auffälligkeiten:
# - Quantity <= 0
# - UnitPrice <= 0
# - Rechnungsnummern, die mit "C" beginnen

# %% [markdown]
# ## 5. Analysepopulation definieren
#
# Für die folgenden Übungen verwenden wir nur reguläre Verkäufe mit positiver Menge und positivem Preis. Fehlende Customer IDs dürfen für Bestellanalysen zunächst bestehen bleiben.

# %%
# TODO 3: Erzeugt sales mit regulären Verkäufen.
# Bedingung: Quantity > 0, UnitPrice > 0 und keine InvoiceNo mit "C"

sales = ...
print(sales.shape)

# %% [markdown]
# ## 6. Stichprobe und Bias
#
# Diskutiert in der Gruppe:
#
# - Welche Grundgesamtheit repräsentieren diese Daten?
# - Kann man daraus Aussagen über „alle Onlinekäufer“ ableiten?
# - Welche Kunden fehlen möglicherweise systematisch?
# - Welche Rolle spielt der Zeitraum der Datenerhebung?

# %% [markdown]
# ## Management-Checkpoint
#
# Formuliert in höchstens **80 Wörtern** eine Nachricht an die Geschäftsführung: Welche zwei Datenprobleme sind vor einer Umsatzanalyse am wichtigsten und warum?
