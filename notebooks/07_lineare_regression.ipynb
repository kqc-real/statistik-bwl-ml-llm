# %% [markdown]
# <a href="https://colab.research.google.com/github/kqc-real/statistik-bwl-ml-llm/blob/main/notebooks/07_lineare_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# **Studentische Übung · Browser-Version**
#
# 1. Oben auf **„Open in Colab“** klicken.
# 2. In Colab: **Datei → Kopie in Drive speichern**.
# 3. Zellen von oben nach unten ausführen.
#
# > KI- und Coding-Agenten sind erlaubt. Entscheidend ist, dass ihr jede Kennzahl, Grafik und Modellentscheidung fachlich erklären könnt.

# %% [markdown]
# # Übung 7: Lineare Regression
#
# **Nachfrage prognostizieren und Fehler messen**
#
# **Datensatz:** UCI Bike Sharing Dataset
# **Dauer:** ca. 90 Minuten
# **Arbeitsform:** Zweiergruppen; KI-Agenten und Coding-Assistenten sind ausdrücklich erlaubt.
#
# > **Kursregel:** Der Agent darf rechnen und Code erzeugen. Ihr müsst jedoch jede Kennzahl, Grafik und Modellentscheidung fachlich erklären können.
#
# Am Ende des Notebooks gibt es einen **Management-Checkpoint**. Dort zählt nicht der Code, sondern eine kurze, belastbare Entscheidungsvorlage.

# %% [markdown]
# ## Lernziele
#
# Nach dieser Übung könnt ihr:
#
# - eine lineare Regression als Prognosemodell trainieren
# - Koeffizienten und Intercept interpretieren
# - MAE, RMSE und R² auf Testdaten bewerten
# - Residuen als Diagnoseinstrument verwenden

# %% [markdown]
# ## Setup

# %%
#@title Setup und Kursdaten laden
import importlib.util
import sys
import urllib.request
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 50)
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")
RNG = np.random.default_rng(42)

MODULE_URL = "https://raw.githubusercontent.com/kqc-real/statistik-bwl-ml-llm/main/course_data.py"
module_path = Path("course_data.py")
if not module_path.exists():
    urllib.request.urlretrieve(MODULE_URL, module_path)

spec = importlib.util.spec_from_file_location("course_data", module_path)
course_data = importlib.util.module_from_spec(spec)
sys.modules["course_data"] = course_data
spec.loader.exec_module(course_data)

df = course_data.bike_sharing()
print("Datensatz: bike_sharing")
print("Form:", df.shape)
df.head()

# %% [markdown]
# ## 1. Geschäftssituation
#
# Der Betreiber möchte die tägliche Zahl der Ausleihen für die Kapazitätsplanung prognostizieren.

# %% [markdown]
# ## 2. Baseline und zeitlicher Split
#
# Wir trainieren auf früheren Tagen und testen auf späteren Tagen. Das ist für Zeitdaten realistischer als ein zufälliges Mischen.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# TODO 1: Sortiert nach instant. Verwendet die ersten 80 % als Training,
# die letzten 20 % als Test.

ordered = ...
split = ...
train = ...
test = ...

# %% [markdown]
# ## 3. Einfaches Modell: nur Temperatur

# %%
# TODO 2: Trainiert LinearRegression mit temp als Feature.
# Prognostiziert den Testdatensatz.

model_temp = ...
pred_temp = ...

# %% [markdown]
# ## 4. Modellgüte

# %%
# TODO 3: Berechnet MAE, RMSE und R² für den Testdatensatz.

# %% [markdown]
# ## 5. Mehrere Einflussgrößen
#
# Verwendet nur Informationen, die vor dem Prognosetag plausibel verfügbar sein könnten. `casual` und `registered` bleiben ausgeschlossen.

# %%
# TODO 4: Trainiert ein Modell mit
# temp, hum, windspeed, weathersit, workingday, season, yr

features = [...]
model_multi = ...
pred_multi = ...
regression_metrics(test["cnt"], pred_multi)

# %% [markdown]
# ## 6. Residuen

# %%
# TODO 5: Residuen = beobachtet - prognostiziert.
# Zeichnet Residuen gegen Prognosen.

# %% [markdown]
# > **Agentenauftrag**
# > Kopiert bei Bedarf diesen Auftrag in euren Coding-Agenten:
# >
# > *„Erkläre mir MAE, RMSE und R² für ein Nachfrageprognosemodell. Welche Kennzahl kann ein Manager direkt in 'Fahrrädern pro Tag' interpretieren? Welche reagiert stärker auf große Fehler?“*
# >
# > Prüft den Vorschlag des Agenten. Übernehmt keine Auswertung, die ihr nicht fachlich begründen könnt.

# %% [markdown]
# ## 7. Koeffizienten mit Vorsicht lesen

# %%
# TODO 6: Zeigt die Koeffizienten des Mehrvariablenmodells als Tabelle.

# %% [markdown]
# ## Management-Checkpoint
#
# Entscheidet, welches Modell eingesetzt werden soll. Nennt Test-MAE, einen Vorteil und eine Einschränkung. Maximal 70 Wörter.
