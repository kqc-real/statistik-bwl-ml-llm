# %% [markdown]
# <a href="https://colab.research.google.com/github/kqc-real/statistik-bwl-ml-llm/blob/main/notebooks/03_wahrscheinlichkeit_bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# **Studentische Übung · Browser-Version**
#
# 1. Oben auf **„Open in Colab“** klicken.
# 2. In Colab: **Datei → Kopie in Drive speichern**.
# 3. Zellen von oben nach unten ausführen.
#
# > KI- und Coding-Agenten sind erlaubt. Entscheidend ist, dass ihr jede Kennzahl, Grafik und Modellentscheidung fachlich erklären könnt.

# %% [markdown]
# # Übung 3: Wahrscheinlichkeit und Bayes
#
# **Kaufwahrscheinlichkeiten ohne Modellierungszauber**
#
# **Datensatz:** UCI Online Shoppers Purchasing Intention
# **Dauer:** ca. 90 Minuten
# **Arbeitsform:** Zweiergruppen; KI-Agenten und Coding-Assistenten sind ausdrücklich erlaubt.
#
# > **Kursregel:** Der Agent darf rechnen und Code erzeugen. Ihr müsst jedoch jede Kennzahl, Grafik und Modellentscheidung fachlich erklären können.
#
# Am Ende des Notebooks gibt es einen **Management-Checkpoint**. Dort zählt nicht der Code, sondern eine kurze, belastbare Entscheidungsvorlage.

# %% [markdown]
# ## Lernziele
#
# Nach dieser Übung könnt ihr:
#
# - empirische Wahrscheinlichkeiten aus Daten schätzen
# - bedingte Wahrscheinlichkeiten korrekt lesen
# - die Richtung einer Bedingung unterscheiden
# - den Satz von Bayes mit natürlichen Häufigkeiten interpretieren

# %% [markdown]
# ## Setup

# %%
#@title Setup und Kursdaten laden
import importlib.util
import sys
import urllib.request
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 50)
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")
RNG = np.random.default_rng(42)

MODULE_URL = "https://raw.githubusercontent.com/kqc-real/statistik-bwl-ml-llm/main/course_data.py"
module_path = Path("course_data.py")
if not module_path.exists():
    urllib.request.urlretrieve(MODULE_URL, module_path)

spec = importlib.util.spec_from_file_location("course_data", module_path)
course_data = importlib.util.module_from_spec(spec)
sys.modules["course_data"] = course_data
spec.loader.exec_module(course_data)

df = course_data.online_shoppers()
print("Datensatz: online_shoppers")
print("Form:", df.shape)
df.head()

# %% [markdown]
# ## 1. Geschäftssituation
#
# Ein E-Commerce-Team möchte Kaufwahrscheinlichkeiten während einer Sitzung verstehen. Heute wird noch kein Vorhersagemodell trainiert.

# %% [markdown]
# ## 2. Grundwahrscheinlichkeit

# %%
# TODO 1: Schätzt P(Kauf) aus den Daten.

p_buy = ...
p_buy

# %% [markdown]
# ## 3. Bedingte Wahrscheinlichkeiten
#
# Vergleicht die Kaufwahrscheinlichkeit für wiederkehrende und neue Besucher.

# %%
# TODO 2: Berechnet
# P(Kauf | Returning_Visitor)
# P(Kauf | New_Visitor)

# %% [markdown]
# ## 4. Bayes: Richtung der Bedingung
#
# Achtung: `P(Kauf | Wiederkehrer)` ist nicht dasselbe wie `P(Wiederkehrer | Kauf)`.

# %%
# TODO 3:
# a) Berechnet P(Returning | Kauf) direkt aus den Daten.
# b) Berechnet dieselbe Wahrscheinlichkeit mit Bayes:
#    P(Kauf | Returning) * P(Returning) / P(Kauf)

p_returning_given_buy_direct = ...
p_returning_given_buy_bayes = ...

# %% [markdown]
# > **Agentenauftrag**
# > Kopiert bei Bedarf diesen Auftrag in euren Coding-Agenten:
# >
# > *„Erkläre mir den Unterschied zwischen P(A|B) und P(B|A) anhand eines E-Commerce-Beispiels. Verwende natürliche Häufigkeiten pro 1.000 Sitzungen und keine Urnen.“*
# >
# > Prüft den Vorschlag des Agenten. Übernehmt keine Auswertung, die ihr nicht fachlich begründen könnt.

# %% [markdown]
# ## 5. Segmentierung
#
# Definiert `HighPageValue` als PageValues oberhalb des 75%-Quantils und untersucht die Kaufwahrscheinlichkeit.

# %%
# TODO 4: Erzeugt HighPageValue und berechnet
# P(Kauf | HighPageValue) und P(Kauf | nicht HighPageValue).

# %% [markdown]
# ## 6. Natürliche Häufigkeiten
#
# Stellt euch 1.000 zufällig ausgewählte Sitzungen vor. Berechnet erwartete Anzahlen für Kauf / kein Kauf und Returning / New. Erstellt dafür eine Kreuztabelle auf Basis der beobachteten Anteile.

# %%
# TODO 5: Kreuztabelle der relativen Häufigkeiten erstellen
# und auf 1.000 Sitzungen skalieren.

# %% [markdown]
# ## Management-Checkpoint
#
# Eine Marketingmanagerin sagt: „Die meisten Käufe kommen von wiederkehrenden Besuchern, also sind wiederkehrende Besucher fast sichere Käufer.“ Widerlegt oder bestätigt die Aussage mit genau zwei Wahrscheinlichkeiten.
