# %% [markdown]
# <a href="https://colab.research.google.com/github/kqc-real/statistik-bwl-ml-llm/blob/main/notebooks/04_zufallsvariablen_verteilungen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# **Studentische Übung · Browser-Version**
#
# 1. Oben auf **„Open in Colab“** klicken.
# 2. In Colab: **Datei → Kopie in Drive speichern**.
# 3. Zellen von oben nach unten ausführen.
#
# > KI- und Coding-Agenten sind erlaubt. Entscheidend ist, dass ihr jede Kennzahl, Grafik und Modellentscheidung fachlich erklären könnt.

# %% [markdown]
# # Übung 4: Zufallsvariablen und Verteilungen
#
# **Warum reale Geschäftsdaten selten glockenförmig sind**
#
# **Datensatz:** UCI Online Retail
# **Dauer:** ca. 90 Minuten
# **Arbeitsform:** Zweiergruppen; KI-Agenten und Coding-Assistenten sind ausdrücklich erlaubt.
#
# > **Kursregel:** Der Agent darf rechnen und Code erzeugen. Ihr müsst jedoch jede Kennzahl, Grafik und Modellentscheidung fachlich erklären können.
#
# Am Ende des Notebooks gibt es einen **Management-Checkpoint**. Dort zählt nicht der Code, sondern eine kurze, belastbare Entscheidungsvorlage.

# %% [markdown]
# ## Lernziele
#
# Nach dieser Übung könnt ihr:
#
# - eine empirische Zufallsvariable definieren
# - Erwartungswert, Varianz und Standardabweichung interpretieren
# - Schiefe und Extremwerte erkennen
# - empirische und theoretische Verteilungen unterscheiden

# %% [markdown]
# ## Setup

# %%
#@title Setup und Kursdaten laden
import importlib.util
import sys
import urllib.request
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 50)
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")
RNG = np.random.default_rng(42)

MODULE_URL = "https://raw.githubusercontent.com/kqc-real/statistik-bwl-ml-llm/main/course_data.py"
module_path = Path("course_data.py")
if not module_path.exists():
    urllib.request.urlretrieve(MODULE_URL, module_path)

spec = importlib.util.spec_from_file_location("course_data", module_path)
course_data = importlib.util.module_from_spec(spec)
sys.modules["course_data"] = course_data
spec.loader.exec_module(course_data)

df = course_data.online_retail()
print("Datensatz: online_retail")
print("Form:", df.shape)
df.head()

# %% [markdown]
# ## 1. Geschäftssituation
#
# Das Controlling möchte verstehen, warum „durchschnittliche“ Bestellwerte oft irreführend sind und wie sich reale Verteilungen von idealisierten Modellen unterscheiden.

# %%
# TODO 1: Bereitet reguläre Verkäufe vor und aggregiert Revenue pro InvoiceNo.

order_value = ...

# %% [markdown]
# ## 2. Zufallsvariable definieren
#
# Wir betrachten eine zufällig ausgewählte reguläre Bestellung. Die Zufallsvariable **X** ist ihr Bestellwert.

# %%
# TODO 2: Schätzt E(X), Median(X), Var(X) und SD(X).

# %% [markdown]
# ## 3. Empirische Verteilung

# %%
# TODO 3: Zeichnet die empirische Verteilung bis zum 99%-Quantil.

# %% [markdown]
# ## 4. Normalverteilung als Referenz
#
# Vergleicht die beobachtete Variable mit einer simulierten Normalverteilung mit gleichem Mittelwert und gleicher Standardabweichung.

# %%
# TODO 4: Simuliert normal_values mit gleicher Länge, gleichem Mittelwert
# und gleicher Standardabweichung wie x. Zeichnet ein eigenes Histogramm.

normal_values = ...

# %% [markdown]
# > **Agentenauftrag**
# > Kopiert bei Bedarf diesen Auftrag in euren Coding-Agenten:
# >
# > *„Vergleiche eine stark rechtsschiefe empirische Verteilung mit einer Normalverteilung. Welche Folgen hat die Schiefe für Mittelwert, Median, Standardabweichung und die Wahrscheinlichkeit extremer Werte? Antworte ohne Code.“*
# >
# > Prüft den Vorschlag des Agenten. Übernehmt keine Auswertung, die ihr nicht fachlich begründen könnt.

# %% [markdown]
# ## 5. Wahrscheinlichkeit aus der empirischen Verteilung
#
# Schätzt die Wahrscheinlichkeit, dass ein zufällig ausgewählter Bestellwert über dem 90%-Quantil liegt. Prüft danach, warum das Ergebnis definitionsgemäß ungefähr 10 % ist.

# %%
# TODO 5

q90 = ...
prob_above_q90 = ...

# %% [markdown]
# ## 6. Transformation
#
# Untersucht `log1p(OrderValue)` und vergleicht Mittelwert und Median der transformierten Variable.

# %%
# TODO 6: Log-Transformation und Histogramm

# %% [markdown]
# ## Management-Checkpoint
#
# Ein Dashboard zeigt nur den durchschnittlichen Bestellwert. Formuliert eine fachlich begründete Verbesserung des Dashboards in höchstens 60 Wörtern.
