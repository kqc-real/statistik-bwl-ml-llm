# %% [markdown]
# <a href="https://colab.research.google.com/github/kqc-real/statistik-bwl-ml-llm/blob/main/notebooks/05_stichprobe_unsicherheit_bootstrap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# **Studentische Übung · Browser-Version**
#
# 1. Oben auf **„Open in Colab“** klicken.
# 2. In Colab: **Datei → Kopie in Drive speichern**.
# 3. Zellen von oben nach unten ausführen.
#
# > KI- und Coding-Agenten sind erlaubt. Entscheidend ist, dass ihr jede Kennzahl, Grafik und Modellentscheidung fachlich erklären könnt.

# %% [markdown]
# # Übung 5: Stichprobe und Unsicherheit
#
# **Bootstrap statt Tabellenbuch**
#
# **Datensatz:** UCI Online Retail
# **Dauer:** ca. 90 Minuten
# **Arbeitsform:** Zweiergruppen; KI-Agenten und Coding-Assistenten sind ausdrücklich erlaubt.
#
# > **Kursregel:** Der Agent darf rechnen und Code erzeugen. Ihr müsst jedoch jede Kennzahl, Grafik und Modellentscheidung fachlich erklären können.
#
# Am Ende des Notebooks gibt es einen **Management-Checkpoint**. Dort zählt nicht der Code, sondern eine kurze, belastbare Entscheidungsvorlage.

# %% [markdown]
# ## Lernziele
#
# Nach dieser Übung könnt ihr:
#
# - Stichprobenvariabilität empirisch sichtbar machen
# - den Standardfehler als Streuung einer Schätzgröße verstehen
# - ein Bootstrap-Konfidenzintervall berechnen
# - den Einfluss der Stichprobengröße auf Unsicherheit beurteilen

# %% [markdown]
# ## Setup

# %%
#@title Setup und Kursdaten laden
import importlib.util
import sys
import urllib.request
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 50)
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")
RNG = np.random.default_rng(42)

MODULE_URL = "https://raw.githubusercontent.com/kqc-real/statistik-bwl-ml-llm/main/course_data.py"
module_path = Path("course_data.py")
if not module_path.exists():
    urllib.request.urlretrieve(MODULE_URL, module_path)

spec = importlib.util.spec_from_file_location("course_data", module_path)
course_data = importlib.util.module_from_spec(spec)
sys.modules["course_data"] = course_data
spec.loader.exec_module(course_data)

df = course_data.online_retail()
print("Datensatz: online_retail")
print("Form:", df.shape)
df.head()

# %% [markdown]
# ## 1. Geschäftssituation
#
# Die Geschäftsführung kennt den durchschnittlichen Warenkorbwert in einer Stichprobe. Das Controlling fragt: „Wie stabil ist diese Zahl?“

# %%
# TODO 1: Reguläre Verkäufe filtern, Revenue bilden, pro Rechnung aggregieren.

order_value = ...
x = ...

# %% [markdown]
# ## 2. Eine Stichprobe ist nicht die Wahrheit
#
# Zieht wiederholt Stichproben von 100 Bestellungen und beobachtet, wie stark der Mittelwert schwankt.

# %%
# TODO 2: Zieht 500 Stichproben mit n=100 ohne Zurücklegen.
# Speichert jeweils den Mittelwert.

sample_means = []
...

# %%
# TODO 3: Histogramm der Stichprobenmittelwerte

# %% [markdown]
# ## 3. Bootstrap
#
# Nun tun wir so, als hätten wir nur eine Stichprobe von 300 Bestellungen. Mit Bootstrap approximieren wir die Unsicherheit des Mittelwerts.

# %%
# TODO 4:
# 1. Zieht einmalig 300 Bestellungen: observed_sample
# 2. Zieht daraus 2.000 Bootstrap-Stichproben mit Zurücklegen
# 3. Speichert die Mittelwerte

observed_sample = ...
bootstrap_means = []
...

# %% [markdown]
# ## 4. 95%-Bootstrap-Konfidenzintervall

# %%
# TODO 5: Bestimmt das 2,5%- und 97,5%-Quantil.

ci_low, ci_high = ...
print(ci_low, ci_high)

# %% [markdown]
# > **Agentenauftrag**
# > Kopiert bei Bedarf diesen Auftrag in euren Coding-Agenten:
# >
# > *„Erkläre mir ein 95%-Konfidenzintervall für einen Managementbericht. Vermeide die falsche Formulierung, dass der wahre Parameter mit 95 % Wahrscheinlichkeit im bereits berechneten Intervall liegt.“*
# >
# > Prüft den Vorschlag des Agenten. Übernehmt keine Auswertung, die ihr nicht fachlich begründen könnt.

# %% [markdown]
# ## 5. Stichprobengröße vergleichen
#
# Wiederholt die Bootstrap-Analyse für n = 50, 200 und 800. Vergleicht die Intervallbreiten.

# %%
# TODO 6: Funktion bootstrap_ci_width schreiben und anwenden.

# %% [markdown]
# ## Management-Checkpoint
#
# Die Stichprobe liefert einen mittleren Warenkorbwert und ein 95%-Intervall. Formuliert zwei Sätze: einen korrekten Befund und eine falsche Interpretation, die ihr ausdrücklich zurückweist.
