# %% [markdown]
# <a href="https://colab.research.google.com/github/kqc-real/statistik-bwl-ml-llm/blob/main/notebooks/08_logistische_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# **Studentische Übung · Browser-Version**
#
# 1. Oben auf **„Open in Colab“** klicken.
# 2. In Colab: **Datei → Kopie in Drive speichern**.
# 3. Zellen von oben nach unten ausführen.
#
# > KI- und Coding-Agenten sind erlaubt. Entscheidend ist, dass ihr jede Kennzahl, Grafik und Modellentscheidung fachlich erklären könnt.

# %% [markdown]
# # Übung 8: Logistische Regression
#
# **Von Sitzungsmerkmalen zur Kaufwahrscheinlichkeit**
#
# **Datensatz:** UCI Online Shoppers Purchasing Intention
# **Dauer:** ca. 90 Minuten
# **Arbeitsform:** Zweiergruppen; KI-Agenten und Coding-Assistenten sind ausdrücklich erlaubt.
#
# > **Kursregel:** Der Agent darf rechnen und Code erzeugen. Ihr müsst jedoch jede Kennzahl, Grafik und Modellentscheidung fachlich erklären können.
#
# Am Ende des Notebooks gibt es einen **Management-Checkpoint**. Dort zählt nicht der Code, sondern eine kurze, belastbare Entscheidungsvorlage.

# %% [markdown]
# ## Lernziele
#
# Nach dieser Übung könnt ihr:
#
# - eine logistische Regression trainieren
# - die Sigmoidfunktion als Wahrscheinlichkeitsabbildung verstehen
# - Modellausgaben als Wahrscheinlichkeiten interpretieren
# - Log Loss und ROC-AUC als Gütemaße einordnen

# %% [markdown]
# ## Setup

# %%
#@title Setup und Kursdaten laden
import importlib.util
import sys
import urllib.request
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 50)
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")
RNG = np.random.default_rng(42)

MODULE_URL = "https://raw.githubusercontent.com/kqc-real/statistik-bwl-ml-llm/main/course_data.py"
module_path = Path("course_data.py")
if not module_path.exists():
    urllib.request.urlretrieve(MODULE_URL, module_path)

spec = importlib.util.spec_from_file_location("course_data", module_path)
course_data = importlib.util.module_from_spec(spec)
sys.modules["course_data"] = course_data
spec.loader.exec_module(course_data)

df = course_data.online_shoppers()
print("Datensatz: online_shoppers")
print("Form:", df.shape)
df.head()

# %% [markdown]
# ## 1. Geschäftssituation
#
# Ein E-Commerce-Team möchte während einer Sitzung abschätzen, ob ein Kauf stattfinden wird. Das Ergebnis soll eine **Wahrscheinlichkeit** sein.

# %% [markdown]
# ## 2. Daten vorbereiten

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, roc_auc_score

# TODO 1: Wählt Features und Zielvariable.
# Features: PageValues, ProductRelated_Duration, BounceRates, ExitRates
# Ziel: Revenue
# 75 % Training, 25 % Test, random_state=42, stratify=y

features = [...]
X = ...
y = ...
X_train, X_test, y_train, y_test = ...

# %% [markdown]
# ## 3. Logistische Regression trainieren

# %%
# TODO 2: Trainiert LogisticRegression(max_iter=2000).

model = ...
prob_test = ...

# %% [markdown]
# ## 4. Was bedeutet 0,70?
#
# Beantwortet ohne Code: Wenn das Modell für eine Sitzung 0,70 ausgibt, was bedeutet diese Zahl? Was bedeutet sie ausdrücklich **nicht**?

# %% [markdown]
# ## 5. Sigmoid verstehen
#
# Die logistische Regression bildet einen linearen Score über die Sigmoidfunktion auf den Bereich 0 bis 1 ab.

# %%
# TODO 3: Implementiert sigmoid(z) und berechnet Werte für
# z = [-4, -2, 0, 2, 4]

# %%
# TODO 4: Zeichnet die Sigmoidfunktion für z von -8 bis 8.

# %% [markdown]
# ## 6. Modellgüte als Wahrscheinlichkeitsmodell

# %%
# TODO 5: Berechnet Log Loss und ROC-AUC.

# %% [markdown]
# ## 7. Koeffizienten

# %%
# TODO 6: Erstellt eine Koeffiziententabelle.

# %% [markdown]
# > **Agentenauftrag**
# > Kopiert bei Bedarf diesen Auftrag in euren Coding-Agenten:
# >
# > *„Erkläre einen Koeffizienten der logistischen Regression in Bezug auf Log-Odds und Odds. Zeige auch exp(Koeffizient). Warne davor, den Koeffizienten direkt als Prozentpunktänderung der Wahrscheinlichkeit zu lesen.“*
# >
# > Prüft den Vorschlag des Agenten. Übernehmt keine Auswertung, die ihr nicht fachlich begründen könnt.

# %% [markdown]
# ## Management-Checkpoint
#
# Erklärt einem Marketingmanager in höchstens 70 Wörtern, warum eine Kaufwahrscheinlichkeit nützlicher sein kann als nur „Kauf / kein Kauf“.
