# %% [markdown]
# <a href="https://colab.research.google.com/github/kqc-real/statistik-bwl-ml-llm/blob/main/notebooks/02_deskriptive_statistik_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# **Studentische Übung · Browser-Version**
#
# 1. Oben auf **„Open in Colab“** klicken.
# 2. In Colab: **Datei → Kopie in Drive speichern**.
# 3. Zellen von oben nach unten ausführen.
#
# > KI- und Coding-Agenten sind erlaubt. Entscheidend ist, dass ihr jede Kennzahl, Grafik und Modellentscheidung fachlich erklären könnt.

# %% [markdown]
# # Übung 2: Deskriptive Statistik und EDA
#
# **Vom Transaktionsdatensatz zur Management-Kennzahl**
#
# **Datensatz:** UCI Online Retail
# **Dauer:** ca. 90 Minuten
# **Arbeitsform:** Zweiergruppen; KI-Agenten und Coding-Assistenten sind ausdrücklich erlaubt.
#
# > **Kursregel:** Der Agent darf rechnen und Code erzeugen. Ihr müsst jedoch jede Kennzahl, Grafik und Modellentscheidung fachlich erklären können.
#
# Am Ende des Notebooks gibt es einen **Management-Checkpoint**. Dort zählt nicht der Code, sondern eine kurze, belastbare Entscheidungsvorlage.

# %% [markdown]
# ## Lernziele
#
# Nach dieser Übung könnt ihr:
#
# - Transaktionsdaten sinnvoll aggregieren
# - Lage-, Streuungs- und Quantilmaße interpretieren
# - schiefe Verteilungen grafisch erkennen
# - Kundenkonzentration mit einer einfachen Kennzahl beschreiben

# %% [markdown]
# ## Setup

# %%
#@title Setup und Kursdaten laden
import importlib.util
import sys
import urllib.request
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 50)
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")
RNG = np.random.default_rng(42)

MODULE_URL = "https://raw.githubusercontent.com/kqc-real/statistik-bwl-ml-llm/main/course_data.py"
module_path = Path("course_data.py")
if not module_path.exists():
    urllib.request.urlretrieve(MODULE_URL, module_path)

spec = importlib.util.spec_from_file_location("course_data", module_path)
course_data = importlib.util.module_from_spec(spec)
sys.modules["course_data"] = course_data
spec.loader.exec_module(course_data)

df = course_data.online_retail()
print("Datensatz: online_retail")
print("Form:", df.shape)
df.head()

# %% [markdown]
# ## 1. Geschäftssituation
#
# Die Geschäftsführung fragt: „Wie sieht ein typischer Kauf aus und welche Kunden tragen besonders viel zum Umsatz bei?“

# %% [markdown]
# ## 2. Analysebasis vorbereiten

# %%
# TODO 1: Bereinigt reguläre Verkäufe und erzeugt Revenue = Quantity * UnitPrice.

sales = ...

# %% [markdown]
# ## 3. Von Zeilen zu Bestellungen
#
# Eine Rechnungsnummer kann mehrere Positionen enthalten. Aggregiert daher auf Bestellungsebene.

# %%
# TODO 2: Bildet pro InvoiceNo die Summe von Revenue.
# Nennt das Ergebnis order_value.

order_value = ...
order_value.head()

# %% [markdown]
# > **Agentenauftrag**
# > Kopiert bei Bedarf diesen Auftrag in euren Coding-Agenten:
# >
# > *„Ich habe Bestellwerte in einer pandas-Spalte. Erkläre mir, welche Kennzahlen Mittelwert, Median, Standardabweichung, IQR und Quantile liefern. Erzeuge noch keinen Code. Hilf mir zu entscheiden, welche Kennzahl einen 'typischen' Warenkorb am besten beschreibt.“*
# >
# > Prüft den Vorschlag des Agenten. Übernehmt keine Auswertung, die ihr nicht fachlich begründen könnt.

# %% [markdown]
# ## 4. Typischer Warenkorb

# %%
# TODO 3: Berechnet Mittelwert, Median, Standardabweichung,
# 25%-Quantil, 75%-Quantil und 90%-Quantil.

summary = ...
summary

# %%
# TODO 4: Zeichnet ein Histogramm der Bestellwerte.
# Begrenzung für die Lesbarkeit: nur Werte bis zum 99%-Quantil.

# %% [markdown]
# ## 5. Kundenkonzentration
#
# Für diese Analyse werden nur Verkäufe mit CustomerID verwendet.

# %%
# TODO 5: Aggregiert Revenue pro CustomerID.
# Berechnet anschließend den Umsatzanteil der umsatzstärksten 10 % der Kunden.

customer_revenue = ...
top10_share = ...
top10_share

# %% [markdown]
# ## 6. Interpretation
#
# Beantwortet:
#
# 1. Warum unterscheiden sich Mittelwert und Median?
# 2. Welcher Wert beschreibt den typischen Kauf besser?
# 3. Bedeutet ein hoher Umsatzanteil der Top-10-% automatisch, dass diese Kunden profitabler sind?

# %% [markdown]
# ## Management-Checkpoint
#
# Erstellt drei Sätze: **Kennzahl – Befund – Handlungsimplikation**. Verwendet mindestens eine Lagekennzahl und eine Konzentrationskennzahl.
