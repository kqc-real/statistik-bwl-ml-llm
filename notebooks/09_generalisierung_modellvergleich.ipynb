# %% [markdown]
# <a href="https://colab.research.google.com/github/kqc-real/statistik-bwl-ml-llm/blob/main/notebooks/09_generalisierung_modellvergleich.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# **Studentische Übung · Browser-Version**
#
# 1. Oben auf **„Open in Colab“** klicken.
# 2. In Colab: **Datei → Kopie in Drive speichern**.
# 3. Zellen von oben nach unten ausführen.
#
# > KI- und Coding-Agenten sind erlaubt. Entscheidend ist, dass ihr jede Kennzahl, Grafik und Modellentscheidung fachlich erklären könnt.

# %% [markdown]
# # Übung 9: Generalisierung und Modellvergleich
#
# **Warum das beste Trainingsmodell oft nicht das beste Modell ist**
#
# **Datensatz:** UCI Online Shoppers Purchasing Intention
# **Dauer:** ca. 90 Minuten
# **Arbeitsform:** Zweiergruppen; KI-Agenten und Coding-Assistenten sind ausdrücklich erlaubt.
#
# > **Kursregel:** Der Agent darf rechnen und Code erzeugen. Ihr müsst jedoch jede Kennzahl, Grafik und Modellentscheidung fachlich erklären können.
#
# Am Ende des Notebooks gibt es einen **Management-Checkpoint**. Dort zählt nicht der Code, sondern eine kurze, belastbare Entscheidungsvorlage.

# %% [markdown]
# ## Lernziele
#
# Nach dieser Übung könnt ihr:
#
# - eine Baseline als Mindeststandard verwenden
# - Trainings- und Testgüte unterscheiden
# - Overfitting an einem flexiblen Modell erkennen
# - Precision, Recall und Schwellenwerte geschäftlich interpretieren

# %% [markdown]
# ## Setup

# %%
#@title Setup und Kursdaten laden
import importlib.util
import sys
import urllib.request
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 50)
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")
RNG = np.random.default_rng(42)

MODULE_URL = "https://raw.githubusercontent.com/kqc-real/statistik-bwl-ml-llm/main/course_data.py"
module_path = Path("course_data.py")
if not module_path.exists():
    urllib.request.urlretrieve(MODULE_URL, module_path)

spec = importlib.util.spec_from_file_location("course_data", module_path)
course_data = importlib.util.module_from_spec(spec)
sys.modules["course_data"] = course_data
spec.loader.exec_module(course_data)

df = course_data.online_shoppers()
print("Datensatz: online_shoppers")
print("Form:", df.shape)
df.head()

# %% [markdown]
# ## 1. Geschäftssituation
#
# Ein Team vergleicht mehrere Modelle zur Kaufvorhersage. Das Ziel ist nicht, auf bekannten Daten gut auszusehen, sondern auf **neuen Sitzungen** zu generalisieren.

# %% [markdown]
# ## 2. Train/Test-Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    confusion_matrix, roc_auc_score
)

features = ["PageValues", "ProductRelated_Duration", "BounceRates", "ExitRates"]
X = df[features]
y = df["Revenue"].astype(int)

# TODO 1: 70 % Training, 30 % Test, random_state=42, stratify=y

X_train, X_test, y_train, y_test = ...

# %% [markdown]
# ## 3. Baseline zuerst
#
# Eine Baseline sagt immer die häufigste Klasse voraus.

# %%
# TODO 2: Erzeugt baseline_pred, die immer 0 prognostiziert.
# Berechnet die Accuracy.

baseline_pred = ...

# %% [markdown]
# ## 4. Zwei Modelle vergleichen

# %%
# TODO 3: Trainiert
# a) LogisticRegression(max_iter=2000)
# b) DecisionTreeClassifier(max_depth=None, random_state=42)

logit = ...
tree = ...

# %% [markdown]
# ## 5. Trainingserfolg ist nicht Generalisierung

# %%
# TODO 4: Vergleicht Train- und Test-Accuracy beider Modelle.

# %% [markdown]
# ## 6. Precision, Recall und Confusion Matrix

# %%
# TODO 5: Berechnet für die logistische Regression:
# Accuracy, Precision, Recall, ROC-AUC und Confusion Matrix.

pred = ...
prob = ...

# %% [markdown]
# > **Agentenauftrag**
# > Kopiert bei Bedarf diesen Auftrag in euren Coding-Agenten:
# >
# > *„Ich habe ein Klassifikationsmodell für Kauf / kein Kauf. Erkläre Accuracy, Precision und Recall anhand von Marketingkosten und entgangenen Käufen. Zeige, warum eine hohe Accuracy bei seltener Zielklasse irreführend sein kann.“*
# >
# > Prüft den Vorschlag des Agenten. Übernehmt keine Auswertung, die ihr nicht fachlich begründen könnt.

# %% [markdown]
# ## 7. Schwellenwert als Geschäftsentscheidung
#
# Standardmäßig wird oft 0,5 verwendet. Vergleicht 0,3, 0,5 und 0,7.

# %%
# TODO 6: Berechnet Precision und Recall für die Schwellenwerte 0.3, 0.5, 0.7.

# %% [markdown]
# ## Management-Checkpoint
#
# Ihr habt Budget, nur 10 % der Sitzungen mit einer teuren Maßnahme anzusprechen. Welche Modellkennzahl ist dann besonders wichtig? Begründet die Wahl in höchstens 80 Wörtern.
